# %% [markdown]
# <a href="https://colab.research.google.com/github/Chum4k3r/ex_eletroacusticaI/blob/main/EA_DADO1_Exemplos4_5_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dados para simulação dos exemplos 4, 5 e 6 (circuitos acústicos)

# %% [markdown]
# ## Exemplo 4

# %% [markdown]
# ![Screenshot_20210615_102937.png](data:image/png;base64,...)

# %% [markdown]
# $\Large V = 500\ \text{ml}$
#
# $\Large l_{T} = 3\ \text{cm}$
#
# $\Large a = 1.5\ \text{cm}$

# %% [markdown]
# ## Exemplo 5

# %% [markdown]
# ![Screenshot_20210615_103008.png](data:image/png;base64,...)

# %% [markdown]
# $\Large a_{1} = 28.575\ \text{mm} \xrightarrow{} \text{duto da esquerda}$
#
# $\Large l_{T1} = 50\ \text{cm} \xrightarrow{} \text{duto da esquerda}$
#
# $\Large a_{2} = 31.25\ \text{mm} \xrightarrow{} \text{duto da direita}$
#
# $\Large l_{T2} = 40\ \text{cm} \xrightarrow{} \text{duto da direita}$
#
# $\Large a_{c} = 57.15\ \text{mm}$
#
# $\Large l_{c} = 30\ \text{cm}$

# %% [markdown]
# ## Exemplo 6

# %% [markdown]
# ![Screenshot_20210615_103033.png](data:image/png;base64,...)

# %% [markdown]
# $\Large V_{1} = 1\ \text{l}$
#
# $\Large V_{1} = 3\ \text{l}$
#
# $\Large l_{T} = 15\ \text{cm}$
#
# $\Large a = 2\ \text{cm}$
